# %%
import pandas as pd
import numpy as np
from plotnine import *
import seaborn as sns

# %%
train = pd.read_csv('train.csv', header=0)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test = pd.read_csv('test.csv', header=0)
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train['Embarked'] = train.Embarked.astype('category')
test['Embarked'] = test.Embarked.astype('category')

# %%
train['Survived'] = train.Survived.astype('bool')

# %%
train['minor_16'] = train.apply(lambda x: x.Age < 17, axis=1)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1     False       3
# 1            2      True       1
# 2            3      True       3
# 3            4      True       1
# 4            5     False       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  minor_16
# 0      0         A/5 21171   7.2500   NaN        S     False
# 1      0          PC 17599  71.2833   C85        C     False
# 2      0  STON/O2. 3101282   7.9250   NaN        S     False
# 3      0            113803  53.1000  C123        S     False
# ...

# %%
train.sample(10)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 117          118     False       2    Turpin, Mr. William John Robert    male
# 26            27     False       3            Emir, Mr. Farred Chehab    male
# 689          690      True       1  Madill, Miss. Georgette Alexandra  female
# 434          435     False       1          Silvey, Mr. William Baird    male
# 443          444      True       2          Reynaldo, Ms. Encarnacion  female
# 380          381      True       1              Bidois, Miss. Rosalie  female
# 61            62      True       1                Icard, Miss. Amelie  female
# 524          525     False       3                  Kassem, Mr. Fared    male
# 290          291      True       1       Barber, Miss. Ellen "Nellie"  female
# 838          839      True       3                    Chip, Mr. Chang    male
#
#       Age  SibSp  Parch    Ticket      Fare Cabin Embarked  minor_16
# ...

# %% [markdown]
# # Factors

# %% [markdown]
# ## Age

# %%
(ggplot(train)
+ aes(x='Survived', y='Parch', fill="minor_16")
+ geom_jitter())
# Out:
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (-9223371874116150861)>

# %%
(ggplot(train)
+ aes(x='Survived', y='SibSp', fill="minor_16")
+ geom_jitter())
# Out:
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (162738759663)>

# %%
(ggplot(train[train.Sex=='male'])
+ aes(x='Survived', y='SibSp', fill="minor_16")
+ geom_jitter())
# Out:
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (162738759579)>

# %%
(ggplot(train[train.Sex=='female'])
+ aes(x='Survived', y='SibSp', fill="minor_16")
+ geom_jitter())
# Out:
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\Delta\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (-9223371874115992702)>
