# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('shops_01.csv', header=0, encoding='cp949')

# %%
df = df[df.시도명 == '서울특별시']

# %%
df.head()
# Out:
#      상가업소번호          상호명     지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  상권업종중분류명  \
# 1  28498271    비비안아울렛중계점  아울렛중계점         D       소매       D05      의복의류
# 2  28512174  연세정신건강의학과의원     NaN         S       의료       S01        병원
# 3  28499926  독일지멘스보청기은평점     은평점         D       소매       D20  의약/의료품소매
# 4  28490321         서울모드     NaN         Q       음식       Q12    커피점/카페
# 8  11720327    국대떡볶이길음역점    길음역점         Q       음식       Q04        분식
#
#   상권업종소분류코드     상권업종소분류명 표준산업분류코드      표준산업분류명  시도코드    시도명  시군구코드 시군구명  \
# 1    D05A07     셔츠/내의/속옷      NaN          NaN    11  서울특별시  11350  노원구
# 2    S01B99         기타병원      NaN          NaN    11  서울특별시  11110  종로구
# 3    D20A02        보청기판매   G47812   의료용 기구 소매업    11  서울특별시  11380  은평구
# 4    Q12A01  커피전문점/카페/다방   I56220     비알콜 음료점업    11  서울특별시  11680  강남구
# 8    Q04A03        떡볶이전문   I56194  분식 및 김밥 전문점    11  서울특별시  11290  성북구
#
#         행정동코드    행정동명       법정동코드 법정동명                 지번코드  대지구분코드 대지구분명  \
# ...

# %%
df_sports = df[df.상권업종대분류명 == '스포츠']

# %%
df.상권업종대분류명.unique()
# Out:
# array(['소매', '의료', '음식', '생활서비스', '숙박', '학문/교육', '관광/여가/오락', '부동산', '스포츠'],
#       dtype=object)

# %%
df[df['상호명'].str.contains('클라이밍|등반|암벽')]
# Out:
#           상가업소번호            상호명  지점명 상권업종대분류코드  상권업종대분류명 상권업종중분류코드  \
# 56740   24686009  손정준스포츠클라이밍연구소  NaN         D        소매       D05
# 104946  24285350     도봉파워클라이밍센터  NaN         N  관광/여가/오락       N01
# 235118  24374790       세정클라이밍학원  NaN         R     학문/교육       R05
# 365290  12049390          희래등반점  NaN         Q        음식       Q02
#
#             상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드         표준산업분류명  시도코드  \
# 56740           의복의류    D05A01         일반의류   G47416  셔츠 및 기타 의복 소매업    11
# 104946  PC/오락/당구/볼링등    N01A06          볼링장   R91134         볼링장 운영업    11
# 235118     학원-음악미술무용    R05A02  피아노/바이올린/기타   P85620           예술 학원    11
# 365290            중식    Q02A00     중국음식/중국집   I56112         중식 음식점업    11
#
#           시도명  시군구코드  시군구명       행정동코드  행정동명       법정동코드 법정동명  \
# 56740   서울특별시  11200   성동구  1120064500   옥수동  1120011300  옥수동
# 104946  서울특별시  11320   도봉구  1132067000  쌍문2동  1132010500  쌍문동
# 235118  서울특별시  11290   성북구  1129066000  길음1동  1129013400  길음동
# ...

# %%
import folium
geo_df = jmt

map = folium.Map(location=[geo_df['위도'].mean(), geo_df['경도'].mean()], zoom_start=17)

for n in geo_df.index:
    park_name = geo_df['상호명'][n] \
                + ' - ' + geo_df['위치/주소'][n]
    folium.Marker([geo_df['위도'][n], geo_df['경도'][n]], popup=park_name).add_to(map)

map

# %%
map = folium.Map(location=[geo_df['위도'].mean(), geo_df['경도'].mean()], 
                 zoom_start=17, tiles='Stamen Toner')

for n in geo_df.index:
    park_name = geo_df['상호명'][n] \
                + ' - ' + geo_df['위치/주소'][n] \
                + ', 별점: '+ str(geo_df['별점'][n])
    folium.Marker([geo_df['위도'][n], geo_df['경도'][n]], popup=park_name).add_to(map)
    
ourloc = folium.Marker([37.54886648029149, 126.9562337802915], 
                       popup='서울창업허브', 
                       icon=folium.Icon(color='orange', icon='cloud')).add_to(map)
